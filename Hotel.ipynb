# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv("project3_df1.csv")

# %%
print(data)
# Out:
#       Unnamed: 0                                      Name             City  \
# 0              0                                    الريـم           Al Ula
# 1              1         Copper Crown Furnished Apartments   Khamis Mushayt
# 2              2                        فندق راية الشلال 2        Abū Qa‘ar
# 3              3  Four Points by Sheraton Makkah Al Naseem           Makkah
# 4              4                نزل الثريا للوحدات السكنية             Taif
# ...          ...                                       ...              ...
# 1020        1020         Al Corniche Hotel Suites & Villas             Hail
# 1021        1021                        Golden Tower Hotel        Al Jubail
# 1022        1022                        Drr Ramah Suites 2           Riyadh
# 1023        1023          Taj Al Khaleej Furnished Units 2           Ţurayf
# 1024        1024               Shatha Abha Furnished Units             Abha
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1025 non-null   int64
#  1   Name                  1025 non-null   object
#  2   City                  1025 non-null   object
#  3   Price                 1025 non-null   object
#  4   Star_Rating           1025 non-null   int64
#  5   Property_Demand       750 non-null    object
#  6   Property_id           1025 non-null   int64
#  7   Customers_Rating      956 non-null    float64
#  8   Customers_Review      956 non-null    object
#  9   Type_of_room          1024 non-null   object
#  10  reservations_Payment  735 non-null    object
#  11  Canelation            846 non-null    object
#  12  Max_persons           1025 non-null   object
#  13  Bed_type              1006 non-null   object
#  14  Tax                   1025 non-null   object
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  Star_Rating   Property_id  Customers_Rating  Longitude_x  \
# count  1025.000000  1025.000000  1.025000e+03        956.000000  1025.000000
# mean    512.000000     1.707317  2.932536e+06          7.394979    43.330090
# std     296.036315     1.884920  1.974138e+06          1.065163     4.310628
# min       0.000000     0.000000  2.530900e+04          3.400000    35.005600
# 25%     256.000000     0.000000  1.370200e+06          6.700000    39.214104
# 50%     512.000000     0.000000  2.320250e+06          7.500000    42.541455
# 75%     768.000000     3.000000  4.766370e+06          8.200000    46.757680
# max    1024.000000     5.000000  6.402009e+06          9.600000    50.223634
#
#         Latitude_y
# count  1025.000000
# mean     23.403023
# std       2.941714
# min      16.848112
# 25%      21.464557
# 50%      24.159421
# 75%      26.269904
# max      31.676857

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'City', 'Price', 'Star_Rating', 'Property_Demand',
#        'Property_id', 'Customers_Rating', 'Customers_Review', 'Type_of_room',
#        'reservations_Payment', 'Canelation', 'Max_persons', 'Bed_type', 'Tax',
#        'Review_title', 'Credit_card', 'Breakfst_included', 'Longitude_x',
#        'Latitude_y', 'Link'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Name                      0
# City                      0
# Price                     0
# Star_Rating               0
# Property_Demand         275
# Property_id               0
# Customers_Rating         69
# Customers_Review         69
# Type_of_room              1
# reservations_Payment    290
# Canelation              179
# Max_persons               0
# Bed_type                 19
# Tax                       0
# Review_title             69
# Credit_card             321
# Breakfst_included       941
# Longitude_x               0
# Latitude_y                0
# Link                      0
# dtype: int64

# %%
data.head(5)
# Out:
#    Unnamed: 0                                      Name             City  \
# 0           0                                    الريـم           Al Ula
# 1           1         Copper Crown Furnished Apartments   Khamis Mushayt
# 2           2                        فندق راية الشلال 2        Abū Qa‘ar
# 3           3  Four Points by Sheraton Makkah Al Naseem           Makkah
# 4           4                نزل الثريا للوحدات السكنية             Taif
#
#      Price  Star_Rating                          Property_Demand  Property_id  \
# 0  SAR 179            5   Only 1 room left like this on our site      6330099
# 1  SAR 195            5  Only 2 rooms like this left on our site      5326174
# 2  SAR 200            5  Only 3 rooms like this left on our site      5987844
# 3  SAR 225            5  Only 5 rooms like this left on our site      3889445
# 4  SAR 250            5                                      NaN      6284346
#
# ...

# %%
data = data.drop(['Tax','Review_title', 'Credit_card', 'Breakfst_included', 'Longitude_x','Latitude_y', 'Link'],axis=1)

# %%
data.head()
# Out:
#    Unnamed: 0                                      Name             City  \
# 0           0                                    الريـم           Al Ula
# 1           1         Copper Crown Furnished Apartments   Khamis Mushayt
# 2           2                        فندق راية الشلال 2        Abū Qa‘ar
# 3           3  Four Points by Sheraton Makkah Al Naseem           Makkah
# 4           4                نزل الثريا للوحدات السكنية             Taif
#
#      Price  Star_Rating                          Property_Demand  Property_id  \
# 0  SAR 179            5   Only 1 room left like this on our site      6330099
# 1  SAR 195            5  Only 2 rooms like this left on our site      5326174
# 2  SAR 200            5  Only 3 rooms like this left on our site      5987844
# 3  SAR 225            5  Only 5 rooms like this left on our site      3889445
# 4  SAR 250            5                                      NaN      6284346
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Name                      0
# City                      0
# Price                     0
# Star_Rating               0
# Property_Demand         275
# Property_id               0
# Customers_Rating         69
# Customers_Review         69
# Type_of_room              1
# reservations_Payment    290
# Canelation              179
# Max_persons               0
# Bed_type                 19
# dtype: int64

# %%
data.nunique()
# Out:
# Unnamed: 0              1025
# Name                    1024
# City                     112
# Price                    312
# Star_Rating                6
# Property_Demand           14
# Property_id             1025
# Customers_Rating          56
# Customers_Review         610
# Type_of_room             236
# reservations_Payment       1
# Canelation                 1
# Max_persons               12
# Bed_type                  65
# dtype: int64

# %%
data['City'].nuniqueque()
# Out:
# 112

# %%
print(data['City'].unique())
# Out:
# [' Al Ula' ' Khamis Mushayt' ' Abū Qa‘ar' ' Makkah' ' Taif' ' An Nikāshah'
#  ' Riyadh' ' Al Yarmouk, Al Khobar' ' Ajyad, Makkah' ' Al Ahsa' ' Hail'
#  ' Al Khobar' ' Half Moon Bay' ' Al Hamra, Jeddah' ' Abha'
#  ' Al Worood, Riyadh' ' Najran' ' Al Hofuf' ' Jazan' ' Al Olaya, Riyadh'
#  ' Central Madinah, Al Madinah' ' Al Rawda, Jeddah' ' Al Jubail'
#  ' Al Andalus, Jeddah' ' Al Shatiea, Jeddah' ' Diplomatic Quarter, Riyadh'
#  ' Jeddah' ' Buraydah' ' Yanbu' ' North Obhr, Jeddah'
#  ' Al Olayya, Al Khobar' ' ‘Afīf' ' Al Salamah, Jeddah' ' Ar Riyad'
#  ' Al ‘Aqrabīyah' ' Dammam' ' Sari Street, Jeddah' ' Hera Street, Jeddah'
#  ' Ţurayf' ' Al Sulimania, Riyadh' ' Nimrān' ' Al Baha' ' Nughaylah'
#  ' Al Fayşalīyah' ' Sharurah' ' Unayzah' ' Al Khafji' ' Hafr Al Baten'
#  ' King Abdul Aziz Road, Jeddah' ' Al Majmaah' ' Ahad Rafidah'
#  ' Al Madinah' ' Qurish Street, Jeddah' ' Al Malaz, Riyadh'
#  ' Palestine  Street, Jeddah' ' Al Tahlia Street, Jeddah' ' Al Rass'
# ...

# %%
dataY = data['City'].value_counts()

# %%
data.groupby('City').mean()['Customers_Rating'].sort_values(ascending=[False])
# Out:
# City
#  Tanomah                         9.000000
#  Hotat bani tamim                9.000000
#  Al Kāmil                        8.900000
#  Ad Dawādimī                     8.900000
#  King Abdullah Economic City     8.900000
#  Diplomatic Quarter, Riyadh      8.766667
#  King Abdul Aziz Road, Jeddah    8.750000
#  ‘Afīf                           8.700000
#  Durat  Alarous                  8.700000
#  Unayzah                         8.640000
# Name: Customers_Rating, dtype: float64

# %%
dataX = data.groupby('City').mean()['Customers_Rating'].sort_values(ascending=[False])

# %%
dataX
# Out:
# City
#  Tanomah                        9.0
#  Hotat bani tamim               9.0
#  Al Kāmil                       8.9
#  Ad Dawādimī                    8.9
#  King Abdullah Economic City    8.9
#                                ...
#  An Nikāshah                    NaN
#  Ar Riyad                       NaN
#  Hajlah                         NaN
#  Jarwal                         NaN
#  Qal'at Bishah                  NaN
# Name: Customers_Rating, Length: 112, dtype: float64

# %%
dataY
# Out:
#  Riyadh                  132
#  Jeddah                   98
#  Dammam                   59
#  Makkah                   50
#  Al Olayya, Al Khobar     38
#                         ...
#  Al Mikhlaf                1
#  Tanomah                   1
#  Hajlah                    1
#  Sulţānah                  1
#  Ad Darb                   1
# Name: City, Length: 112, dtype: int64

# %%
plt.pyplot.scatter(dataY,dataX)
